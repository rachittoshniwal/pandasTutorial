# %% [markdown]
# ### Data Source:
#
# https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd

# %% [markdown]
# ## Read csv files

# %%
df = pd.read_csv('data/covid19-og.csv')
df
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      14/04/2020   14      4  2020     58       3             Afghanistan
# 1      13/04/2020   13      4  2020     52       0             Afghanistan
# 2      12/04/2020   12      4  2020     34       3             Afghanistan
# 3      11/04/2020   11      4  2020     37       0             Afghanistan
# 4      10/04/2020   10      4  2020     61       1             Afghanistan
# 5      09/04/2020    9      4  2020     56       3             Afghanistan
# 6      08/04/2020    8      4  2020     30       4             Afghanistan
# 7      07/04/2020    7      4  2020     38       0             Afghanistan
# 8      06/04/2020    6      4  2020     29       2             Afghanistan
# 9      05/04/2020    5      4  2020     35       1             Afghanistan
# 10     04/04/2020    4      4  2020      0       0             Afghanistan
# ...

# %%
# 1
pd.read_csv('data/covid19-og.csv', header=0)
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      14/04/2020   14      4  2020     58       3             Afghanistan
# 1      13/04/2020   13      4  2020     52       0             Afghanistan
# 2      12/04/2020   12      4  2020     34       3             Afghanistan
# 3      11/04/2020   11      4  2020     37       0             Afghanistan
# 4      10/04/2020   10      4  2020     61       1             Afghanistan
# 5      09/04/2020    9      4  2020     56       3             Afghanistan
# 6      08/04/2020    8      4  2020     30       4             Afghanistan
# 7      07/04/2020    7      4  2020     38       0             Afghanistan
# 8      06/04/2020    6      4  2020     29       2             Afghanistan
# 9      05/04/2020    5      4  2020     35       1             Afghanistan
# 10     04/04/2020    4      4  2020      0       0             Afghanistan
# ...

# %%
# 2
pd.read_csv('data/covid19-nocols.csv', names=['date', 'day', 'month', 'year', 'cases', 'deaths',
                                             'country', 'code', 'code2', 'population'])
# Out:
#              date  day  month  year  cases  deaths      country code code2  \
# 0      14/04/2020   14      4  2020     58       3  Afghanistan   AF   AFG
# 1      13/04/2020   13      4  2020     52       0  Afghanistan   AF   AFG
# 2      12/04/2020   12      4  2020     34       3  Afghanistan   AF   AFG
# 3      11/04/2020   11      4  2020     37       0  Afghanistan   AF   AFG
# 4      10/04/2020   10      4  2020     61       1  Afghanistan   AF   AFG
# 5      09/04/2020    9      4  2020     56       3  Afghanistan   AF   AFG
# 6      08/04/2020    8      4  2020     30       4  Afghanistan   AF   AFG
# 7      07/04/2020    7      4  2020     38       0  Afghanistan   AF   AFG
# 8      06/04/2020    6      4  2020     29       2  Afghanistan   AF   AFG
# 9      05/04/2020    5      4  2020     35       1  Afghanistan   AF   AFG
# 10     04/04/2020    4      4  2020      0       0  Afghanistan   AF   AFG
# ...

# %%
# 3

pd.read_csv('data/covid19-og.csv', index_col=0)
# Out:
#             day  month  year  cases  deaths countriesAndTerritories geoId  \
# dateRep
# 14/04/2020   14      4  2020     58       3             Afghanistan    AF
# 13/04/2020   13      4  2020     52       0             Afghanistan    AF
# 12/04/2020   12      4  2020     34       3             Afghanistan    AF
# 11/04/2020   11      4  2020     37       0             Afghanistan    AF
# 10/04/2020   10      4  2020     61       1             Afghanistan    AF
# 09/04/2020    9      4  2020     56       3             Afghanistan    AF
# 08/04/2020    8      4  2020     30       4             Afghanistan    AF
# 07/04/2020    7      4  2020     38       0             Afghanistan    AF
# 06/04/2020    6      4  2020     29       2             Afghanistan    AF
# 05/04/2020    5      4  2020     35       1             Afghanistan    AF
# 04/04/2020    4      4  2020      0       0             Afghanistan    AF
# ...

# %%
# 4

pd.read_csv('data/covid19-og.csv', usecols=[0, 4, 6])
# Out:
#           dateRep  cases countriesAndTerritories
# 0      14/04/2020     58             Afghanistan
# 1      13/04/2020     52             Afghanistan
# 2      12/04/2020     34             Afghanistan
# 3      11/04/2020     37             Afghanistan
# 4      10/04/2020     61             Afghanistan
# 5      09/04/2020     56             Afghanistan
# 6      08/04/2020     30             Afghanistan
# 7      07/04/2020     38             Afghanistan
# 8      06/04/2020     29             Afghanistan
# 9      05/04/2020     35             Afghanistan
# 10     04/04/2020      0             Afghanistan
# 11     03/04/2020     43             Afghanistan
# 12     02/04/2020     26             Afghanistan
# 13     01/04/2020     25             Afghanistan
# 14     31/03/2020     27             Afghanistan
# 15     30/03/2020      8             Afghanistan
# 16     29/03/2020     15             Afghanistan
# 17     28/03/2020     16             Afghanistan
# ...

# %%
# 5

pd.read_csv('data/covid19-og.csv', nrows=15)
# Out:
#        dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0   14/04/2020   14      4  2020     58       3             Afghanistan    AF
# 1   13/04/2020   13      4  2020     52       0             Afghanistan    AF
# 2   12/04/2020   12      4  2020     34       3             Afghanistan    AF
# 3   11/04/2020   11      4  2020     37       0             Afghanistan    AF
# 4   10/04/2020   10      4  2020     61       1             Afghanistan    AF
# 5   09/04/2020    9      4  2020     56       3             Afghanistan    AF
# 6   08/04/2020    8      4  2020     30       4             Afghanistan    AF
# 7   07/04/2020    7      4  2020     38       0             Afghanistan    AF
# 8   06/04/2020    6      4  2020     29       2             Afghanistan    AF
# 9   05/04/2020    5      4  2020     35       1             Afghanistan    AF
# 10  04/04/2020    4      4  2020      0       0             Afghanistan    AF
# ...

# %%
# 6

pd.read_csv('data/covid19-skiprows.csv', skiprows=5)
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      14/04/2020   14      4  2020     58       3             Afghanistan
# 1      13/04/2020   13      4  2020     52       0             Afghanistan
# 2      12/04/2020   12      4  2020     34       3             Afghanistan
# 3      11/04/2020   11      4  2020     37       0             Afghanistan
# 4      10/04/2020   10      4  2020     61       1             Afghanistan
# 5      09/04/2020    9      4  2020     56       3             Afghanistan
# 6      08/04/2020    8      4  2020     30       4             Afghanistan
# 7      07/04/2020    7      4  2020     38       0             Afghanistan
# 8      06/04/2020    6      4  2020     29       2             Afghanistan
# 9      05/04/2020    5      4  2020     35       1             Afghanistan
# 10     04/04/2020    4      4  2020      0       0             Afghanistan
# ...

# %%
# 7

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10742 entries, 0 to 10741
# Data columns (total 10 columns):
# dateRep                    10742 non-null object
# day                        10742 non-null int64
# month                      10742 non-null int64
# year                       10742 non-null int64
# cases                      10742 non-null int64
# deaths                     10742 non-null int64
# countriesAndTerritories    10742 non-null object
# geoId                      10711 non-null object
# countryterritoryCode       10635 non-null object
# popData2018                10675 non-null float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 839.3+ KB

# %%
pd.read_csv('data/covid19-og.csv', parse_dates=[0]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10742 entries, 0 to 10741
# Data columns (total 10 columns):
# dateRep                    10742 non-null datetime64[ns]
# day                        10742 non-null int64
# month                      10742 non-null int64
# year                       10742 non-null int64
# cases                      10742 non-null int64
# deaths                     10742 non-null int64
# countriesAndTerritories    10742 non-null object
# geoId                      10711 non-null object
# countryterritoryCode       10635 non-null object
# popData2018                10675 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 839.3+ KB

# %% [markdown]
# 1. header
# 2. names
# 3. index_col
# 4. usecols
# 5. nrows
# 6. skiprows
# 7. parse_dates

# %% [markdown]
# ## Read Excel files

# %%
pd.read_excel('data/covid19.xlsx')
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-04-14   14      4  2020     58       3             Afghanistan
# 1     2020-04-13   13      4  2020     52       0             Afghanistan
# 2     2020-04-12   12      4  2020     34       3             Afghanistan
# 3     2020-04-11   11      4  2020     37       0             Afghanistan
# 4     2020-04-10   10      4  2020     61       1             Afghanistan
# 5     2020-04-09    9      4  2020     56       3             Afghanistan
# 6     2020-04-08    8      4  2020     30       4             Afghanistan
# 7     2020-04-07    7      4  2020     38       0             Afghanistan
# 8     2020-04-06    6      4  2020     29       2             Afghanistan
# 9     2020-04-05    5      4  2020     35       1             Afghanistan
# 10    2020-04-04    4      4  2020      0       0             Afghanistan
# 11    2020-04-03    3      4  2020     43       0             Afghanistan
# ...

# %% [markdown]
# ## Read JSON files

# %%
pd.read_json('data/admits.json').sort_index()
# Out:
#       gpa    gre toefl workex research  admit
# 0    6.80  326.0   106      0       3+      0
# 1    8.24  305.0   114    3.5        0      1
# 2    6.56  312.0   116      1        2      1
# 3    7.62  326.0   107      3        3      1
# 4    6.01  314.0    87      2        2      1
# 5    6.09  317.0   116      0       3+      0
# 6   10.90  302.0   118      5        3      1
# 7    7.01  326.0    89    1.5        2      1
# 8    6.67  304.0    87    1.5        1      1
# 9    7.03  301.0    93      0        0      0
# 10   7.78  329.0    82      4        1      1
# 11   5.73  327.0   104      4        1      0
# 12   8.14  328.0    81    0.5        0      1
# 13   5.52  312.0    93    0.5        2      0
# 14    NaN  327.0    86      5        0      0
# 15   6.81  329.0   106    0.5        1      0
# 16   4.73  319.0    92    1.5        1      1
# 17   6.62  337.0    84    1.5        2      1
# 18   5.43  332.0    84    3.5        3      1
# ...

# %%
admits = pd.read_csv('data/admits.csv')
admits
# Out:
#       gpa    gre toefl workex research  admit
# 0    6.80  326.0   106      0       3+      0
# 1    8.24  305.0   114    3.5        0      1
# 2    6.56  312.0   116      1        2      1
# 3    7.62  326.0   107      3        3      1
# 4    6.01  314.0    87      2        2      1
# 5    6.09  317.0   116      0       3+      0
# 6   10.90  302.0   118      5        3      1
# 7    7.01  326.0    89    1.5        2      1
# 8    6.67  304.0    87    1.5        1      1
# 9    7.03  301.0    93      0        0      0
# 10   7.78  329.0    82      4        1      1
# 11   5.73  327.0   104      4        1      0
# 12   8.14  328.0    81    0.5        0      1
# 13   5.52  312.0    93    0.5        2      0
# 14    NaN  327.0    86      5        0      0
# 15   6.81  329.0   106    0.5        1      0
# 16   4.73  319.0    92    1.5        1      1
# 17   6.62  337.0    84    1.5        2      1
# 18   5.43  332.0    84    3.5        3      1
# ...

# %%
admits.to_json(orient='columns')
# Out:
# '{"gpa":{"0":6.8,"1":8.24,"2":6.56,"3":7.62,"4":6.01,"5":6.09,"6":10.9,"7":7.01,"8":6.67,"9":7.03,"10":7.78,"11":5.73,"12":8.14,"13":5.52,"14":null,"15":6.81,"16":4.73,"17":6.62,"18":5.43,"19":6.46,"20":6.68,"21":6.37,"22":5.94,"23":5.59,"24":7.01,"25":4.05,"26":5.86,"27":7.06,"28":10.0,"29":6.27,"30":8.92,"31":6.75,"32":4.84,"33":7.78,"34":6.18,"35":7.68,"36":6.74,"37":8.79,"38":9.16,"39":5.67,"40":8.62,"41":6.41,"42":7.34,"43":7.53,"44":6.92,"45":8.51,"46":7.98,"47":5.1,"48":8.88,"49":5.85,"50":8.94,"51":5.48,"52":8.03,"53":7.08,"54":5.19,"55":null,"56":6.38,"57":7.68,"58":6.53,"59":6.17,"60":7.18,"61":6.86,"62":5.94,"63":6.89,"64":5.41,"65":7.69,"66":7.07,"67":6.77,"68":5.5,"69":8.31,"70":9.05,"71":6.41,"72":null,"73":7.24,"74":6.56,"75":8.86,"76":6.54,"77":8.32,"78":8.86,"79":7.63,"80":6.69,"81":6.62,"82":4.11,"83":6.81,"84":7.05,"85":5.29,"86":7.6,"87":7.89,"88":6.75,"89":8.28,"90":8.08,"91":6.48,"92":5.27,"93":6.11,"94":7.0,"95":4.96,"96":6.13,"97":8.65,"98":5.79,"99":6.05},"gr
# ...

# %%
admits.to_json(orient='values')
# Out:
# '[[6.8,326.0,"106","0","3+",0],[8.24,305.0,"114","3.5","0",1],[6.56,312.0,"116","1","2",1],[7.62,326.0,"107","3","3",1],[6.01,314.0,"87","2","2",1],[6.09,317.0,"116","0","3+",0],[10.9,302.0,"118","5","3",1],[7.01,326.0,"89","1.5","2",1],[6.67,304.0,"87","1.5","1",1],[7.03,301.0,"93","0","0",0],[7.78,329.0,"82","4","1",1],[5.73,327.0,"104","4","1",0],[8.14,328.0,"81","0.5","0",1],[5.52,312.0,"93","0.5","2",0],[null,327.0,"86","5","0",0],[6.81,329.0,"106","0.5","1",0],[4.73,319.0,"92","1.5","1",1],[6.62,337.0,"84","1.5","2",1],[5.43,332.0,"84","3.5","3",1],[6.46,331.0,"81","5+","1",0],[6.68,321.0,"82","2.5","3+",1],[6.37,307.0,"102","5+","1",1],[5.94,311.0,"118","1","3",0],[5.59,333.0,"116","3.5","2",1],[7.01,301.0,"119","4.5","1",1],[4.05,331.0,"105","0.5","3",1],[5.86,334.0,"101","3","1",0],[7.06,325.0,"106","0.5","0",1],[10.0,306.0,"103","2","0",0],[6.27,330.0,"106","2","0",1],[8.92,311.0,"91","0","3+",1],[6.75,309.0,"92","3.5","3+",1],[4.84,338.0,"90","3.5","1",0],[7.78,305.0,"116"
# ...

# %%
admits.to_json(orient='index')
# Out:
# '{"0":{"gpa":6.8,"gre":326.0,"toefl":"106","workex":"0","research":"3+","admit":0},"1":{"gpa":8.24,"gre":305.0,"toefl":"114","workex":"3.5","research":"0","admit":1},"2":{"gpa":6.56,"gre":312.0,"toefl":"116","workex":"1","research":"2","admit":1},"3":{"gpa":7.62,"gre":326.0,"toefl":"107","workex":"3","research":"3","admit":1},"4":{"gpa":6.01,"gre":314.0,"toefl":"87","workex":"2","research":"2","admit":1},"5":{"gpa":6.09,"gre":317.0,"toefl":"116","workex":"0","research":"3+","admit":0},"6":{"gpa":10.9,"gre":302.0,"toefl":"118","workex":"5","research":"3","admit":1},"7":{"gpa":7.01,"gre":326.0,"toefl":"89","workex":"1.5","research":"2","admit":1},"8":{"gpa":6.67,"gre":304.0,"toefl":"87","workex":"1.5","research":"1","admit":1},"9":{"gpa":7.03,"gre":301.0,"toefl":"93","workex":"0","research":"0","admit":0},"10":{"gpa":7.78,"gre":329.0,"toefl":"82","workex":"4","research":"1","admit":1},"11":{"gpa":5.73,"gre":327.0,"toefl":"104","workex":"4","research":"1","admit":0},"12":{"gpa":8.14,"gr
# ...

# %%
admits.to_json('data/split_json.json', orient='split')

# %%
pd.read_json('data/split_json.json', orient='split')
# Out:
#       gpa    gre toefl workex research  admit
# 0    6.80  326.0   106      0       3+      0
# 1    8.24  305.0   114    3.5        0      1
# 2    6.56  312.0   116      1        2      1
# 3    7.62  326.0   107      3        3      1
# 4    6.01  314.0    87      2        2      1
# 5    6.09  317.0   116      0       3+      0
# 6   10.90  302.0   118      5        3      1
# 7    7.01  326.0    89    1.5        2      1
# 8    6.67  304.0    87    1.5        1      1
# 9    7.03  301.0    93      0        0      0
# 10   7.78  329.0    82      4        1      1
# 11   5.73  327.0   104      4        1      0
# 12   8.14  328.0    81    0.5        0      1
# 13   5.52  312.0    93    0.5        2      0
# 14    NaN  327.0    86      5        0      0
# 15   6.81  329.0   106    0.5        1      0
# 16   4.73  319.0    92    1.5        1      1
# 17   6.62  337.0    84    1.5        2      1
# 18   5.43  332.0    84    3.5        3      1
# ...

# %%
admits.to_json(orient='records')
# Out:
# '[{"gpa":6.8,"gre":326.0,"toefl":"106","workex":"0","research":"3+","admit":0},{"gpa":8.24,"gre":305.0,"toefl":"114","workex":"3.5","research":"0","admit":1},{"gpa":6.56,"gre":312.0,"toefl":"116","workex":"1","research":"2","admit":1},{"gpa":7.62,"gre":326.0,"toefl":"107","workex":"3","research":"3","admit":1},{"gpa":6.01,"gre":314.0,"toefl":"87","workex":"2","research":"2","admit":1},{"gpa":6.09,"gre":317.0,"toefl":"116","workex":"0","research":"3+","admit":0},{"gpa":10.9,"gre":302.0,"toefl":"118","workex":"5","research":"3","admit":1},{"gpa":7.01,"gre":326.0,"toefl":"89","workex":"1.5","research":"2","admit":1},{"gpa":6.67,"gre":304.0,"toefl":"87","workex":"1.5","research":"1","admit":1},{"gpa":7.03,"gre":301.0,"toefl":"93","workex":"0","research":"0","admit":0},{"gpa":7.78,"gre":329.0,"toefl":"82","workex":"4","research":"1","admit":1},{"gpa":5.73,"gre":327.0,"toefl":"104","workex":"4","research":"1","admit":0},{"gpa":8.14,"gre":328.0,"toefl":"81","workex":"0.5","research":"0","ad
# ...

# %%
admits.to_json(orient='table')
# Out:
# '{"schema": {"fields":[{"name":"index","type":"integer"},{"name":"gpa","type":"number"},{"name":"gre","type":"number"},{"name":"toefl","type":"string"},{"name":"workex","type":"string"},{"name":"research","type":"string"},{"name":"admit","type":"integer"}],"primaryKey":["index"],"pandas_version":"0.20.0"}, "data": [{"index":0,"gpa":6.8,"gre":326.0,"toefl":"106","workex":"0","research":"3+","admit":0},{"index":1,"gpa":8.24,"gre":305.0,"toefl":"114","workex":"3.5","research":"0","admit":1},{"index":2,"gpa":6.56,"gre":312.0,"toefl":"116","workex":"1","research":"2","admit":1},{"index":3,"gpa":7.62,"gre":326.0,"toefl":"107","workex":"3","research":"3","admit":1},{"index":4,"gpa":6.01,"gre":314.0,"toefl":"87","workex":"2","research":"2","admit":1},{"index":5,"gpa":6.09,"gre":317.0,"toefl":"116","workex":"0","research":"3+","admit":0},{"index":6,"gpa":10.9,"gre":302.0,"toefl":"118","workex":"5","research":"3","admit":1},{"index":7,"gpa":7.01,"gre":326.0,"toefl":"89","workex":"1.5","researc
# ...

# %% [markdown]
# 1. orient='columns'
# 2. orient='index'
# 3. orient='values'
# 4. orient='records'
# 5. orient='table'
# 6. orient='split'

# %% [markdown]
# ## Read HTML

# %%
htm = pd.read_html('https://en.wikipedia.org/wiki/Twitter', match='Employees')
htm
# Out:
# [                                                    0  \
#  0                                                 NaN
#  1   Screenshot The default page shown to logged-ou...
#  2                                    Type of business
#  3                                        Type of site
#  4                                        Available in
#  5                                           Traded as
#  6                                             Founded
#  7                                        Headquarters
#  8                                         Area served
#  9                                          Founder(s)
#  10                                         Key people
#  11                                           Industry
#  12                                            Revenue
#  13                                   Operating income
#  14                                         Net income
#  15                                       Total assets
# ...

# %%
len(htm)
# Out:
# 2

# %%
htm[1]
# Out:
#         Year  Revenuein mil. US$ Net incomein mil. US$  \
# 0  2010[259]                  28                   −67
# 1  2011[259]                 106                  −164
# 2  2012[259]                 317                   −79
# 3  2013[259]                 665                  −645
# 4  2014[260]                1403                  −578
# 5  2015[261]                2218                  −521
# 6  2016[262]                2530                  −457
# 7  2017[263]                2443                  −108
# 8  2018[264]                3042                  1206
#
#    Total assetsin mil. US$  Employees
# 0                        0        NaN
# 1                      721        NaN
# 2                      832        NaN
# 3                     3366     2712.0
# 4                     5583     3638.0
# 5                     6442     3898.0
# 6                     6870     3583.0
# 7                     7412     3372.0
# 8                    10163     3900.0

# %% [markdown]
# ## Read Clipboard

# %%
pd.read_clipboard()
# Out:
#       name  gre
# 0     jack  325
# 1     anna  329
# 2     mike  300
# 3  jasmine  338

# %%
pd.read_clipboard()
# Out:
#        dateRep  day  month  year  cases  deaths countriesAndTerritories
# 0   14-04-2020   14      4  2020     58       3             Afghanistan
# 1   13-04-2020   13      4  2020     52       0             Afghanistan
# 2   12-04-2020   12      4  2020     34       3             Afghanistan
# 3   11-04-2020   11      4  2020     37       0             Afghanistan
# 4   10-04-2020   10      4  2020     61       1             Afghanistan
# 5   09-04-2020    9      4  2020     56       3             Afghanistan
# 6   08-04-2020    8      4  2020     30       4             Afghanistan
# 7   07-04-2020    7      4  2020     38       0             Afghanistan
# 8   06-04-2020    6      4  2020     29       2             Afghanistan
# 9   05-04-2020    5      4  2020     35       1             Afghanistan
# 10  04-04-2020    4      4  2020      0       0             Afghanistan
# 11  03-04-2020    3      4  2020     43       0             Afghanistan
# ...

# %%
pd.read_clipboard()
# Out:
#       name    gre
# 0     jack  325.0
# 1     anna  329.0
# 2      300    NaN
# 3  jasmine  338.0

# %%
admits.to_csv('data/admits_new.csv', index=False)

# %% [markdown]
# # Tasks

# %% [markdown]
# 1. Search Wikipedia for "List of Pokemon" and fetch the table containing names of all the Pokemons to ever grace our lives

# %%
poke = pd.read_html('https://en.wikipedia.org/wiki/List_of_Pok%C3%A9mon', match='No additional Pokémon')

# %%
len(poke)
# Out:
# 1

# %%
poke[0]
# Out:
#               Generation I                                 Generation II  \
#                      Dex #                   Name                  Dex #
# 0                      001              Bulbasaur                    152
# 1                      002                Ivysaur                    153
# 2                      003               Venusaur                    154
# 3                      004             Charmander                    155
# 4                      005             Charmeleon                    156
# 5                      006              Charizard                    157
# 6                      007               Squirtle                    158
# 7                      008              Wartortle                    159
# 8                      009              Blastoise                    160
# 9                      010               Caterpie                    161
# 10                     011                Metapod                    162
# ...

# %% [markdown]
# 2. The FIFA 20 Dataset contains over 18000 footballers. Read in only the top 3000 names in the list and the four columns containing their name, age, nationality and club. Then convert it into a json file using orient = 'values' and then rename the columns to 'A', 'B' and 'C', 'D'

# %%
fifa = pd.read_csv('data/players_fifa20.csv', nrows=3000, usecols=[3, 4, 8, 9])
fifa
# Out:
#                                 long_name  age          nationality  \
# 0          Lionel Andrés Messi Cuccittini   32            Argentina
# 1     Cristiano Ronaldo dos Santos Aveiro   34             Portugal
# 2           Neymar da Silva Santos Junior   27               Brazil
# 3                               Jan Oblak   26             Slovenia
# 4                             Eden Hazard   28              Belgium
# 5                         Kevin De Bruyne   28              Belgium
# 6                   Marc-André ter Stegen   27              Germany
# 7                         Virgil van Dijk   27          Netherlands
# 8                             Luka Modrić   33              Croatia
# 9                    Mohamed  Salah Ghaly   27                Egypt
# 10                          Kylian Mbappé   20               France
# 11                      Kalidou Koulibaly   28              Senegal
# 12                             Harry Kane   25              England
# ...

# %%
fifa.to_json('data/fifa_json.json', orient='values')

# %%
fifa_json = pd.read_json('data/fifa_json.json', orient='values')
fifa_json
# Out:
#                                         0   1                    2  \
# 0          Lionel Andrés Messi Cuccittini  32            Argentina
# 1     Cristiano Ronaldo dos Santos Aveiro  34             Portugal
# 2           Neymar da Silva Santos Junior  27               Brazil
# 3                               Jan Oblak  26             Slovenia
# 4                             Eden Hazard  28              Belgium
# 5                         Kevin De Bruyne  28              Belgium
# 6                   Marc-André ter Stegen  27              Germany
# 7                         Virgil van Dijk  27          Netherlands
# 8                             Luka Modrić  33              Croatia
# 9                    Mohamed  Salah Ghaly  27                Egypt
# 10                          Kylian Mbappé  20               France
# 11                      Kalidou Koulibaly  28              Senegal
# 12                             Harry Kane  25              England
# ...

# %%
fifa_json.columns = ['A', 'B', 'C', 'D'] # manually setting the column names

# %%
fifa_json
# Out:
#                                         A   B                    C  \
# 0          Lionel Andrés Messi Cuccittini  32            Argentina
# 1     Cristiano Ronaldo dos Santos Aveiro  34             Portugal
# 2           Neymar da Silva Santos Junior  27               Brazil
# 3                               Jan Oblak  26             Slovenia
# 4                             Eden Hazard  28              Belgium
# 5                         Kevin De Bruyne  28              Belgium
# 6                   Marc-André ter Stegen  27              Germany
# 7                         Virgil van Dijk  27          Netherlands
# 8                             Luka Modrić  33              Croatia
# 9                    Mohamed  Salah Ghaly  27                Egypt
# 10                          Kylian Mbappé  20               France
# 11                      Kalidou Koulibaly  28              Senegal
# 12                             Harry Kane  25              England
# ...

# %% [markdown]
# ## Thank you! and see you soon!
